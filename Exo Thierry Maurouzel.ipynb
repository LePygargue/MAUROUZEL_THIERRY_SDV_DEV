# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mower_market_snapshot.csv')

# %%
data.shape
# Out:
# (1399, 1)

# %%
data.head()
# Out:
#   capacity;failure_rate;id;margin;price;prod_cost;product_type;quality;warranty;market_share;attractiveness
# 0  10.492623311991721;0.04252798088681092;18377;6...
# 1  20.273730444538863;0.037896368225955296;19363;...
# 2  20.19045691648912;0.039111245954194296;19641;7...
# 3  27.220131037450034;0.04130311679867133;18728;6...
# 4  16.370911056135107;0.037938171867880455;18722;...

# %%
data = pd.read_csv('mower_market_snapshot.csv', delimiter=";")

# %%
data.head()
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  817.085097  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  844.581465  141.48693796090603
#
#   product_type quality warranty  market_share  attractiveness
# 0  auto-portee     Low     3ans      0.006360        0.650648
# 1  auto-portee     Low   3 ans.      0.006840        0.699792
# 2  auto-portee     Low    3_ans      0.006179        0.632129
# 3  auto-portee     Low   3 anss      0.007925        0.810730
# 4  auto-portee  Medium    3ans.      0.007406        0.757614

# %%
data.columns
# Out:
# Index(['capacity', 'failure_rate', 'id', 'margin', 'price', 'prod_cost',
#        'product_type', 'quality', 'warranty', 'market_share',
#        'attractiveness'],
#       dtype='object')

# %%
data.describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
data['prod_cost'].describe()
# Out:
# count     1399
# unique    1334
# top          0
# freq        20
# Name: prod_cost, dtype: object

# %%
data = data.fillna(data['prod_cost'].mean)

# %%
data['prod_cost'].describe()
# Out:
# count     1399
# unique    1334
# top          0
# freq        20
# Name: prod_cost, dtype: object

# %%
data.describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
data['warranty'].describe()
# Out:
# count      1399
# unique       27
# top       1 an.
# freq        103
# Name: warranty, dtype: object

# %%
data.groupby('warranty').describe()
# Out:
#          capacity                                                         \
#             count       mean        std        min        25%        50%
# warranty
# 1 an        101.0  56.485466  15.861327   0.053793  50.341477  58.248277
# 1 an.       103.0  57.240128  16.574681   0.047045  51.975511  59.420541
# 1 ans        86.0  56.335148  18.333214   0.045343  53.159006  58.990871
# 1_an         91.0  56.601431  16.762759   0.048375  52.572727  59.249653
# 1_an.        95.0  56.939026  17.854989   0.043732  50.162879  57.353412
# 1_ans        96.0  58.804766  13.242733   0.045784  52.182209  58.248806
# 1an          94.0  57.810775  19.209506   0.047216  50.191096  61.284304
# 1an.         84.0  57.774969  15.271760   0.058588  50.433142  59.748918
# 1ans         94.0  58.091988  18.837429   0.043362  50.806912  58.898600
# 2 ans        48.0  38.522000  12.620453   0.026014  32.274530  37.033415
# 2 ans.       45.0  34.897815  14.727013   0.031817  31.145765  37.496280
# ...

# %%
data.warranty.unique()
# Out:
# array(['3ans', '3 ans.', '3_ans', '3 anss', '3ans.', '3 ans', '3_ans.',
#        '3_anss', '3anss', '2 ans', '2 anss', '2anss', '2_ans', '2ans',
#        '2_ans.', '2 ans.', '2_anss', '2ans.', '1 an', '1an', '1_an.',
#        '1ans', '1an.', '1_ans', '1_an', '1 an.', '1 ans'], dtype=object)

# %%
copy = market.copy()
copy['warranty'] = copy['warranty'].replace({r'^(\d).*$' : r'\1'}, regex=True)
copy.groupby('warranty')['price'].describe()
# Out:
#           count        mean         std        min         25%         50%  \
# warranty
# 1         844.0  104.479012  141.064059  62.855737   71.639465   74.351156
# 2         413.0  385.068490   86.231363  62.162200  368.073290  380.532676
# 3         142.0  821.349177  146.095136  69.359766  819.375259  846.982790
#
#                  75%         max
# warranty
# 1          77.413470  910.237658
# 2         395.330818  895.908032
# 3         882.497669  964.973926

# %%
copy['warranty'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
data['price'].describe()
# Out:
# count    1399.000000
# mean      260.075165
# std       259.949127
# min        62.162200
# 25%        73.379425
# 50%        78.439753
# 75%       384.265263
# max       964.973926
# Name: price, dtype: float64

# %%
data[data['price'] < 301]
# Out:
#        capacity  failure_rate     id      margin      price  \
# 47    25.136228      0.044026  19549  618.616295  69.359766
# 103   18.889544      0.036835  19194  661.693700  77.249896
# 126   12.417808      0.037797  19638  672.153234  74.156037
# 166   39.703060      0.073723  18870  248.010000  70.271198
# 170   34.857361      0.114097  18964  241.552664  72.970497
# ...         ...           ...    ...         ...        ...
# 1393  40.831294      0.217289  18950   62.296416  69.391858
# 1394  44.959895      0.234647  18451   63.662561  75.161102
# 1395  59.356058      0.253694  18663   64.014543  75.395132
# 1397  66.855435      0.244948  18946   58.697122  68.491318
# 1398  54.712713      0.177143  19017   64.259212  74.955428
#
#                                               prod_cost product_type quality  \
# 47                                                    0  auto-portee  Medium
# 103                                                 -64  auto-portee     Low
# ...

# %%
data[data['price'] > 301]
data[data['price'] < 501]
# Out:
#        capacity  failure_rate     id      margin       price  \
# 47    25.136228      0.044026  19549  618.616295   69.359766
# 62    15.627623      0.041714  19448  657.152001  359.675157
# 64    18.669448      0.036297  19368  738.279214  424.738557
# 100   28.029561      0.040033  18993  746.108663  350.216029
# 103   18.889544      0.036835  19194  661.693700   77.249896
# ...         ...           ...    ...         ...         ...
# 1393  40.831294      0.217289  18950   62.296416   69.391858
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 47                     0  auto-portee  Medium    3ans.      0.008874
# 62                   -64  auto-portee     Low    3 ans      0.006839
# ...

# %%
def category_price(price):
    if price <= 301:
        return '0-300'
    elif (price >= 300) & (price <= 500):
        return '301 - 500'
    elif price >= 501:
        return '500++'

# %%
data['price'] = data['price'].map(category_price)

# %%
data['price']
# Out:
# 0       500++
# 1       500++
# 2       500++
# 3       500++
# 4       500++
#         ...
# 1394    0-300
# 1395    0-300
# 1396    500++
# 1397    0-300
# 1398    0-300
# Name: price, Length: 1399, dtype: object

# %%
data.head()
# Out:
#     capacity  failure_rate     id      margin  price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  500++  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  500++  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  500++  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  500++  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  500++  141.48693796090603
#
#   product_type quality warranty  market_share  attractiveness
# 0  auto-portee     Low     3ans      0.006360        0.650648
# 1  auto-portee     Low   3 ans.      0.006840        0.699792
# 2  auto-portee     Low    3_ans      0.006179        0.632129
# 3  auto-portee     Low   3 anss      0.007925        0.810730
# 4  auto-portee  Medium    3ans.      0.007406        0.757614

# %%
data['price'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
